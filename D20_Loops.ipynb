# %%
area=[33,44,565,343,65567,4345,534,343,343,3434]

for a in area:
    print("Area is:", a)
# Out:
# Area is: 33
# Area is: 44
# Area is: 565
# Area is: 343
# Area is: 65567
# Area is: 4345
# Area is: 534
# Area is: 343
# Area is: 343
# Area is: 3434
