# %%
print("Connected")
# Out:
# Connected

# %%
my_dict={
    'name':'akmal',
    'grade':'A',
    }
print(type(my_dict))
# Out:
# <class 'dict'>

# %%
student = {
   "name": "Ali",
   "age": 20,
   "department": "AI"
}
print(student)
# Out:
# {'name': 'Ali', 'age': 20, 'department': 'AI'}

# %%
print(student['name'])
# Out:
# Ali

# %%
print(student.get('age'))
# Out:
# 20

# %%
student['section']='2A'

# %%
print(student)
# Out:
# {'name': 'Ali', 'age': 20, 'department': 'AI', 'section': '2A'}

# %%
student['age']=23

# %%
print(student)
# Out:
# {'name': 'Ali', 'age': 23, 'department': 'AI', 'section': '2A'}

# %%
student.pop('section')
# Out:
# '2A'

# %%
student.popitem()
# Out:
# ('department', 'AI')

# %%
student.clear()

# %%
print(student)
# Out:
# {}

# %%
student = {
   "name": "Ali",
   "age": 20
}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student.values()
# Out:
# dict_values(['Ali', 20])
